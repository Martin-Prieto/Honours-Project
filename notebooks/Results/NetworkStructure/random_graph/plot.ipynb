# %%
import sys
import os
module_path = os.path.abspath(os.path.join('../../../../src'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %config InlineBackend.figure_format = 'retina'

# %%
import pandas as pd
from plotting.summaries import *

# %%
df2_div = pd.read_csv('../../../../results/data/random_graph/no_rewire/dis_evbias_0.1.csv')
df2_rw_div = pd.read_csv('../../../../results/data/random_graph/rewire/dis_evbias_0.1.csv')
df2_div = df2_div[~df2_div["Density"].isin([0.015, 0.025, 0.035, 0.045, 0.055, 1, 0.9, 0.7, 0.5, 0.3,  0.09, 0.07, 0.05, 0.03])]
df2_rw_div = df2_rw_div[~df2_rw_div["Density"].isin([0.015, 0.025, 0.035, 0.045, 0.055, 1, 0.9, 0.7, 0.5, 0.3,  0.09, 0.07, 0.05, 0.03])]

# %%
xlim = None
disagreement_densities(df2_div, "Density", xlim)
disagreement_densities(df2_rw_div, "Density", xlim, red=True, bw_adjust=.8)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# ...
