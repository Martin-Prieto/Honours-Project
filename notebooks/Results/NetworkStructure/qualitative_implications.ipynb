# %%
import sys
import os
module_path = os.path.abspath(os.path.join('../../../src'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %config InlineBackend.figure_format = 'retina'

# %%
from society.agents import AnalyticalAgent
from society.structure.network import ArtificialNetwork
from society.beliefs import Distribution, BeliefDistribution
from society.structure import AgentNetwork
from updates import Interactions, UpdateRule
from simulation import Simulation, Insights
from plotting.basic import *
from matplotlib import pyplot as plt
from computations.insights.relative import diversity, disagreement
from plotting.summaries import *
import pandas as pd

# %%
linespace = Distribution(type="linespace", range=(-1,1))
insights = Insights()
simulation = Simulation(1000, insights)
network = ArtificialNetwork(100, "random_graph", p = 0.1)
unique = Distribution(type="unique", value=0.1)
belief_distribution = BeliefDistribution(unique, linespace)
agent_network = AgentNetwork(belief_distribution, network, agent_type=AnalyticalAgent)

# %%
update_rule = UpdateRule(evaluation_bias=0.3, rewire_probability=0)
interactions = Interactions(update_rule, interacting_agents=True)
simulation.run(interactions, agent_network)
er_norw = simulation.insights.belief_evolution
# Out:
# Progress: 100%|██████████| 1000/1000 [00:01<00:00, 867.09it/s]

# %%
update_rule = UpdateRule(evaluation_bias=0.3, rewire_probability=1)
interactions = Interactions(update_rule, interacting_agents=True)
simulation.run(interactions, agent_network)
er_rw = simulation.insights.belief_evolution
# Out:
# Progress: 100%|██████████| 1000/1000 [00:01<00:00, 863.45it/s]

# %%
fig, axs = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(11, 4))

ax_plot_belief_evolution(er_norw, axs[0])
ax_plot_belief_evolution(er_rw, axs[1])

pad = 5 
axs[0].annotate(r'$\rho = 0$', xy=(0.5, 1), xytext=(0, pad),
            xycoords='axes fraction', textcoords='offset points',
            size='large', ha='center', va='baseline')

axs[1].annotate(r'$\rho = 1$', xy=(0.5, 1), xytext=(0, pad),
            xycoords='axes fraction', textcoords='offset points',
            size='large', ha='center', va='baseline')

for ax in axs.flat:
    ax.set(xlabel='Time step', ylabel='Opinion')

for ax in axs.flat:
    ax.label_outer()
fig.show()
fig.savefig("../../../results/plots/Results/Qualitative/random_graph.pdf", bbox_inches="tight")
# Out:
# /var/folders/qj/5zmtfh2n12qb00h_8gwh8zhh0000gn/T/ipykernel_1743/2564425682.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
linespace = Distribution(type="linespace", range=(-1,1))
insights = Insights()
simulation = Simulation(1000, insights)
network = ArtificialNetwork(100, "small_world", k = 4, q=0.8)
unique = Distribution(type="unique", value=0.1)
belief_distribution = BeliefDistribution(unique, linespace)
agent_network = AgentNetwork(belief_distribution, network, agent_type=AnalyticalAgent)

# %%
update_rule = UpdateRule(evaluation_bias=0.3, rewire_probability=0)
interactions = Interactions(update_rule, interacting_agents=True)
simulation.run(interactions, agent_network)
sw_norw = simulation.insights.belief_evolution
# Out:
# Progress: 100%|██████████| 1000/1000 [00:01<00:00, 870.33it/s]

# %%
update_rule = UpdateRule(evaluation_bias=0.3, rewire_probability=1)
interactions = Interactions(update_rule, interacting_agents=True)
simulation.run(interactions, agent_network)
sw_rw = simulation.insights.belief_evolution
# Out:
# Progress: 100%|██████████| 1000/1000 [00:01<00:00, 800.76it/s]

# %%
fig, axs = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(11, 4))

ax_plot_belief_evolution(sw_norw, axs[0])
ax_plot_belief_evolution(sw_rw, axs[1])

pad = 5 
axs[0].annotate(r'$\rho = 0$', xy=(0.5, 1), xytext=(0, pad),
            xycoords='axes fraction', textcoords='offset points',
            size='large', ha='center', va='baseline')

axs[1].annotate(r'$\rho = 1$', xy=(0.5, 1), xytext=(0, pad),
            xycoords='axes fraction', textcoords='offset points',
            size='large', ha='center', va='baseline')

for ax in axs.flat:
    ax.set(xlabel='Time step', ylabel='Opinion')

for ax in axs.flat:
    ax.label_outer()
fig.show()
fig.savefig("../../../results/plots/Results/Qualitative/small_world.pdf", bbox_inches="tight")
# Out:
# /var/folders/qj/5zmtfh2n12qb00h_8gwh8zhh0000gn/T/ipykernel_1743/1083515706.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
linespace = Distribution(type="linespace", range=(-1,1))
insights = Insights()
simulation = Simulation(1000, insights)
network = ArtificialNetwork(100, "barabasi_albert", m = 3)
unique = Distribution(type="unique", value=0.1)
belief_distribution = BeliefDistribution(unique, linespace)
agent_network = AgentNetwork(belief_distribution, network, agent_type=AnalyticalAgent)

# %%
update_rule = UpdateRule(evaluation_bias=0.3, rewire_probability=0)
interactions = Interactions(update_rule, interacting_agents=True)
simulation.run(interactions, agent_network)
sf_norw = simulation.insights.belief_evolution
# Out:
# Progress: 100%|██████████| 1000/1000 [00:01<00:00, 869.59it/s]

# %%
update_rule = UpdateRule(evaluation_bias=0.3, rewire_probability=1)
interactions = Interactions(update_rule, interacting_agents=True)
simulation.run(interactions, agent_network)
sf_rw = simulation.insights.belief_evolution
# Out:
# Progress: 100%|██████████| 1000/1000 [00:01<00:00, 820.65it/s]

# %%
fig, axs = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(11, 4))

ax_plot_belief_evolution(sf_norw, axs[0])
ax_plot_belief_evolution(sf_rw, axs[1])

pad = 5 
axs[0].annotate(r'$\rho = 0$', xy=(0.5, 1), xytext=(0, pad),
            xycoords='axes fraction', textcoords='offset points',
            size='large', ha='center', va='baseline')

axs[1].annotate(r'$\rho = 1$', xy=(0.5, 1), xytext=(0, pad),
            xycoords='axes fraction', textcoords='offset points',
            size='large', ha='center', va='baseline')

for ax in axs.flat:
    ax.set(xlabel='Time step', ylabel='Opinion')

for ax in axs.flat:
    ax.label_outer()
fig.show()
fig.savefig("../../../results/plots/Results/Qualitative/scale_free.pdf", bbox_inches="tight")
# Out:
# /var/folders/qj/5zmtfh2n12qb00h_8gwh8zhh0000gn/T/ipykernel_1743/2647798722.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
