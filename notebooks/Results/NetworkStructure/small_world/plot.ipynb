# %%
import sys
import os
module_path = os.path.abspath(os.path.join('../../../../src'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %config InlineBackend.figure_format = 'retina'

# %%
import pandas as pd
from plotting.summaries import *

# %%
df1_dis = pd.read_csv('../../../../results/data/small_world/new_batch/no_rewire/dis_nobias_0.1,k=2.csv')
df2_dis = pd.read_csv('../../../../results/data/small_world/new_batch/no_rewire/dis_nobias_0.1,k=4.csv')
df3_dis = pd.read_csv('../../../../results/data/small_world/new_batch/no_rewire/dis_nobias_0.1,k=6.csv')
df4_dis = pd.read_csv('../../../../results/data/small_world/new_batch/no_rewire/dis_nobias_0.1,k=8.csv')
df5_dis = pd.read_csv('../../../../results/data/small_world/new_batch/no_rewire/dis_nobias_0.1,k=10.csv')
df5_dis = pd.read_csv('../../../../results/data/small_world/new_batch/no_rewire/dis_nobias_0.1,k=15.csv')
df6_dis = pd.read_csv('../../../../results/data/small_world/new_batch/no_rewire/dis_nobias_0.1,k=20.csv')

df1_dis_rw = pd.read_csv('../../../../results/data/small_world/new_batch/rewire/dis_nobias_0.1,k=2.csv')
df2_dis_rw = pd.read_csv('../../../../results/data/small_world/new_batch/rewire/dis_nobias_0.1,k=4.csv')
df3_dis_rw = pd.read_csv('../../../../results/data/small_world/new_batch/rewire/dis_nobias_0.1,k=6.csv')
df4_dis_rw = pd.read_csv('../../../../results/data/small_world/new_batch/rewire/dis_nobias_0.1,k=8.csv')
df5_dis_rw = pd.read_csv('../../../../results/data/small_world/new_batch/rewire/dis_nobias_0.1,k=10.csv')
df5_dis_rw = pd.read_csv('../../../../results/data/small_world/new_batch/rewire/dis_nobias_0.1,k=15.csv')
df6_dis_rw = pd.read_csv('../../../../results/data/small_world/new_batch/rewire/dis_nobias_0.1,k=20.csv')

# %%
xlim = (0, 0.008)
disagreement_densities(df2_dis, "q", xlim)
disagreement_densities(df2_dis_rw, "q", xlim, red=True)

# %%
xlim = (0, 0.05)
xlim2 = (-0.02, 0.4)
dis_norw = pd.read_csv("../../../../results/data/small_world/new_batch/no_rewire/dis_assimbias_0.1,k=4.csv")
dis_rw = pd.read_csv("../../../../results/data/small_world/new_batch/rewire/dis_assimbias_0.1,k=4.csv")
disagreement_densities(dis_norw, "q", xlim,  ylabel="Clustering q")
disagreement_densities(dis_rw, "q", xlim, red=True,  ylabel="Clustering q")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# ...
