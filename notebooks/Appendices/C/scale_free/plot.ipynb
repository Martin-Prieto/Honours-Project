# %%
import sys
import os
module_path = os.path.abspath(os.path.join('../../../../src'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %config InlineBackend.figure_format = 'retina'

# %%
import pandas as pd
from plotting.summaries import *

# %%
xlim = (0, 0.005)
div_norw = pd.read_csv("../../../../results/data/scale_free/no_rewire/div_nobias_0.1.csv")
div_rw = pd.read_csv("../../../../results/data/scale_free/rewire/div_nobias_0.1.csv")
div_norw = div_norw[div_norw["Diversity"] < 0.34]
div_rw = div_rw[div_rw["Diversity"] <0.34]
diversity_densities(div_norw, "size", xlim,  ylabel="Size n")
plt.savefig("div_norw_nobias_0.1.pdf", bbox_inches = "tight")
diversity_densities(div_rw, "size", xlim, red=True,  ylabel="Size n")
plt.savefig("div_rw_nobias_0.1.pdf", bbox_inches = "tight")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
xlim = (0.01, 0.08)
div_norw = pd.read_csv("../../../../results/data/scale_free/no_rewire/div_assimbias_0.1.csv")
div_rw = pd.read_csv("../../../../results/data/scale_free/rewire/div_assimbias_0.1.csv")
div_norw = div_norw[div_norw["Diversity"] < 0.34]
div_rw = div_rw[div_rw["Diversity"] <0.34]
diversity_densities(div_norw, "size", xlim,  ylabel="Size n")
plt.savefig("div_norw_assimbias_0.1.pdf", bbox_inches = "tight")
diversity_densities(div_rw, "size", xlim, red=True,  ylabel="Size n")
plt.savefig("div_rw_assimbias_0.1.pdf", bbox_inches = "tight")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
xlim = None
div_norw = pd.read_csv("../../../../results/data/scale_free/no_rewire/div_evbias_0.1.csv")
div_rw = pd.read_csv("../../../../results/data/scale_free/rewire/div_evbias_0.1.csv")
div_norw = div_norw[div_norw["Diversity"] < 0.34]
div_rw = div_rw[div_rw["Diversity"] <0.34]
diversity_densities(div_norw, "size", xlim,  ylabel="Size n")
plt.savefig("div_norw_evbias_0.1.pdf", bbox_inches = "tight")
diversity_densities(div_rw, "size", xlim, red=True,  ylabel="Size n")
plt.savefig("div_rw_evbias_0.1.pdf", bbox_inches = "tight")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# ...
