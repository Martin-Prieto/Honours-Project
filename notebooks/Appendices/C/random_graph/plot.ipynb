# %%
import sys
import os
module_path = os.path.abspath(os.path.join('../../../../src'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %config InlineBackend.figure_format = 'retina'

# %%
import pandas as pd
from plotting.summaries import *

# %%
df_div = pd.read_csv('../../../../results/data/random_graph/no_rewire/div_nobias_0.1.csv')
df_rw_div = pd.read_csv('../../../../results/data/random_graph/rewire/div_nobias_0.1.csv')
df_div = df_div[~df_div["Density"].isin([1, 0.9, 0.8, 0.7, 0.6, 0.5,0.4, 0.3, 0.015, 0.025, 0.035, 0.045, 0.055,])]
df_rw_div = df_rw_div[~df_rw_div["Density"].isin([1, 0.9, 0.8, 0.7, 0.6, 0.5,0.4, 0.3, 0.015, 0.025, 0.035, 0.045, 0.055,])]

# %%
xlim = (-0.02, 0.22)
diversity_densities(df_div, "Density", xlim)
diversity_densities(df_rw_div, "Density", xlim, red=True, bw_adjust=.8)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
df_div = pd.read_csv('../../../../results/data/random_graph/no_rewire/div_assimbias_0.1.csv')
df_rw_div = pd.read_csv('../../../../results/data/random_graph/rewire/div_assimbias_0.1.csv')
df_div = df_div[~df_div["Density"].isin([0.015, 0.025, 0.035, 0.045, 0.055, 1, 0.9, 0.7, 0.5, 0.3,  0.09, 0.07, 0.05, 0.03])]
df_rw_div = df_rw_div[~df_rw_div["Density"].isin([0.015, 0.025, 0.035, 0.045, 0.055, 1, 0.9, 0.7, 0.5, 0.3,  0.09, 0.07, 0.05, 0.03])]

# %%
xlim = (-0.02, 0.25)
diversity_densities(df_div, "Density", xlim)
diversity_densities(df_rw_div, "Density", xlim, red=True, bw_adjust=.8)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
df_div = pd.read_csv('../../../../results/data/random_graph/no_rewire/div_evbias_0.1.csv')
df_rw_div = pd.read_csv('../../../../results/data/random_graph/rewire/div_evbias_0.1.csv')
df_div = df_div[~df_div["Density"].isin([0.015, 0.025, 0.035, 0.045, 0.055, 1, 0.9, 0.7, 0.5, 0.3,  0.09, 0.07, 0.05, 0.03])]
df_rw_div = df_rw_div[~df_rw_div["Density"].isin([0.015, 0.025, 0.035, 0.045, 0.055, 1, 0.9, 0.7, 0.5, 0.3,  0.09, 0.07, 0.05, 0.03])]

# %%
xlim = (-0.02, 0.45)
diversity_densities(df_div, "Density", xlim)
diversity_densities(df_rw_div, "Density", xlim, red=True, bw_adjust=.8)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# ...
