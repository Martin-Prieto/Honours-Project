# %%
import sys
import os
module_path = os.path.abspath(os.path.join('../../src'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %config InlineBackend.figure_format = 'retina'

# %%
from computations.insights.complexity import get_execution_times
from plotting.summaries import plot_execution_times

# %%
iterations = 1000
numbers_of_agents = [20, 40, 60, 80, 100]
all_computation_times = []
labels = []

# %%
analytical_computation_times = get_execution_times(numbers_of_agents, iterations, simulation_type="analytical")
all_computation_times.append((numbers_of_agents, analytical_computation_times))
labels.append("Analytical model")
# Out:
# Progress: 100%|██████████| 1000/1000 [00:00<00:00, 4229.98it/s]
# 20 agents, time: 0.24031996726989746
# Progress: 100%|██████████| 1000/1000 [00:00<00:00, 1921.33it/s]
# 40 agents, time: 0.5224061012268066
# Progress: 100%|██████████| 1000/1000 [00:00<00:00, 1166.38it/s]
# 60 agents, time: 0.8608050346374512
# Progress: 100%|██████████| 1000/1000 [00:01<00:00, 859.18it/s]
# 80 agents, time: 1.1704208850860596
# Progress: 100%|██████████| 1000/1000 [00:01<00:00, 656.49it/s]
# 100 agents, time: 1.5293200016021729

# %%
vectorised_computation_times = get_execution_times(numbers_of_agents, iterations, simulation_type="vectorised")
all_computation_times.append((numbers_of_agents, vectorised_computation_times))
labels.append("Vectorised model")
# Out:
# Progress: 100%|██████████| 1000/1000 [00:04<00:00, 234.13it/s]
# 20 agents, time: 4.279839038848877
# Progress: 100%|██████████| 1000/1000 [00:08<00:00, 118.57it/s]
# 40 agents, time: 8.44643783569336
# Progress: 100%|██████████| 1000/1000 [00:12<00:00, 78.44it/s]
# 60 agents, time: 12.768186330795288
# Progress: 100%|██████████| 1000/1000 [00:16<00:00, 59.88it/s]
# 80 agents, time: 16.723301887512207
# Progress: 100%|██████████| 1000/1000 [00:20<00:00, 47.65it/s]
# 100 agents, time: 21.017127752304077

# %%
iterative_computation_times = get_execution_times(numbers_of_agents, iterations, simulation_type="iterative")
all_computation_times.append((numbers_of_agents, iterative_computation_times))
labels.append("Iterative model")
# Out:
# Progress: 100%|██████████| 1000/1000 [00:08<00:00, 112.46it/s]
# 20 agents, time: 8.900914192199707
# Progress: 100%|██████████| 1000/1000 [00:17<00:00, 56.20it/s]
# 40 agents, time: 17.807476043701172
# Progress: 100%|██████████| 1000/1000 [00:26<00:00, 37.78it/s]
# 60 agents, time: 26.487753868103027
# Progress: 100%|██████████| 1000/1000 [00:35<00:00, 28.07it/s]
# 80 agents, time: 35.65691018104553
# Progress: 100%|██████████| 1000/1000 [00:44<00:00, 22.36it/s]
# 100 agents, time: 44.76996183395386

# %%
plot_execution_times(all_computation_times, labels)
